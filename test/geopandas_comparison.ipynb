# %%
import geopandas

# %%
sqrs = geopandas.read_file("./geometries/sqrs_bbox.json")

# %%
sqrs
# Out:
#       DN                                           geometry
# 0     53  POLYGON ((14.06179 52.72569, 14.06179 52.72569...
# 1     55  POLYGON ((14.07329 52.72569, 14.06946 52.72569...
# 2     53  POLYGON ((14.07713 52.72569, 14.07713 52.72569...
# 3     50  POLYGON ((14.08864 52.72569, 14.08096 52.72569...
# 4     48  POLYGON ((14.11165 52.72569, 14.10871 52.72569...
# ...   ..                                                ...
# 2653  55  POLYGON ((14.03129 52.34399, 14.03109 52.34166...
# 2654  51  POLYGON ((13.95125 52.34198, 13.95109 52.34014...
# 2655  51  POLYGON ((14.09940 52.34014, 14.10321 52.34014...
# 2656  51  MULTIPOLYGON (((13.88319 52.34652, 13.88299 52...
# 2657  48  POLYGON ((14.33056 52.37088, 14.32677 52.37102...
#
# [2658 rows x 2 columns]

# %%
plots = geopandas.read_file("./geometries/single_plot_population_bbox.json")

# %%
joined = geopandas.sjoin(plots, sqrs)

# %%
joined
# Out:
#        2017 2018 2019 2020    region  group  \
# 0      56.0  056  058  058     spree      5
# 2      56.0  056  058  058     spree      5
# 3     311.0  591  004  011     spree      5
# 5     311.0  121  411  115     spree      5
# 6     451.0  451  451  451     spree      5
# ...     ...  ...  ...  ...       ...    ...
# 8669  424.0  424  121  424  oderland  >1000
# 8689  131.0  311  131  011  oderland  >1000
# 8690  131.0  311  131  411  oderland  >1000
# 8691  131.0  311  131  011  oderland  >1000
# 8714  131.0  121  121  311  oderland  >1000
#
#                                                location             farmId  \
# 0     {'SHAPE.LEN': 2670.6411110798203, 'SHAPE.AREA'...          spree_5_4
# 2     {'SHAPE.LEN': 6175.36515551835, 'SHAPE.AREA': ...          spree_5_7
# 3     {'SHAPE.LEN': 487.975344053303, 'SHAPE.AREA': ...         spree_5_16
# 5     {'SHAPE.LEN': 2893.54553023185, 'SHAPE.AREA': ...         spree_5_20
# ...

# %%
joined.to_file("./output/merged_plots_geopandas.json", driver='GeoJSON')

# %%
geojson = geopandas.read_file("./geojson.json")

# %%
geojson
# Out:
#         2017 2018 2019 2020    region  group  \
# 0      311.0  058  058  058  oderland   1000
# 1      311.0  172  121  311  oderland    500
# 2      115.0  311  115  115  oderland   1000
# 3      311.0  115  121  131  oderland   1000
# 4      121.0  311  115  172  oderland   1000
# ...      ...  ...  ...  ...       ...    ...
# 22514  424.0  424  452  452     spree  >1000
# 22515  411.0  115  121  411     spree  >1000
# 22516  230.0  115  131  143     spree  >1000
# 22517  411.0  121  411  411     spree   1000
# 22518  177.0  121  125  411     spree   1000
#
#                                                 location            farmId  \
# 0      {'SHAPE.LEN': 522.288950848016, 'SHAPE.AREA': ...  oderland_1000_27
# 1      {'SHAPE.LEN': 417.722828935934, 'SHAPE.AREA': ...    oderland_500_2
# 2      {'SHAPE.LEN': 522.288950848016, 'SHAPE.AREA': ...  oderland_1000_27
# 3      {'SHAPE.LEN': 522.288950848016, 'SHAPE.AREA': ...  oderland_1000_27
# ...

# %%
cities = geopandas.read_file("./geometries/cities.json")

# %%
countries = geopandas.read_file("./geometries/countries.json")

# %%
joined_cities = geopandas.sjoin(cities, countries)

# %%
joined_cities
# Out:
#                        city            city_ascii      lat      lng  \
# 11                    Cairo                 Cairo  30.0561  31.2394
# 150              Alexandria            Alexandria  31.2000  29.9167
# 256                    Giza                  Giza  29.9870  31.2118
# 696       Shubrā al Khaymah     Shubra al Khaymah  30.1286  31.2422
# 1237   Al Maḩallah al Kubrá  Al Mahallah al Kubra  30.9667  31.1667
# ...                     ...                   ...      ...      ...
# 18433             Kilindoni             Kilindoni  -7.9163  39.6500
# 14357           As Sulayyil           As Sulayyil  20.4623  45.5722
# 17212                  Alta                  Alta  69.9686  23.2714
# 22081            Hammerfest            Hammerfest  70.6634  23.6821
# 26446             Calatrava             Calatrava   1.1164   9.4186
#
#                  country iso2 iso3       admin_name  capital  population  \
# 11                 Egypt   EG  EGY       Al Qāhirah  primary  19372000.0
# ...

# %%
joined_cities.to_file("./output/merged_cities_geopandas.json", driver='GeoJSON')

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world.to_file('./output/word.json',driver='GeoJSON')

# %%
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# %%
cities.to_file('./output/cities.json',driver='GeoJSON')
